# %%
# %matplotlib inline

# %%
import numpy
import pylab
import seaborn

# %%
cd ~/dev/sourmash/sourmash_lib/
# Out:
# /Users/philliptbrooks/dev/sourmash/sourmash_lib

# %%
import fig

# %%
cd /Users/philliptbrooks/Dropbox/sourmash/2017_sbt_search_project/rhizosphere_project/signatures/
# Out:
# /Users/philliptbrooks/Dropbox/sourmash/2017_sbt_search_project/rhizosphere_project/signatures

# %%
# %%bash
# for i in 100 500 1000 5000 10000 20000
# do
# ~/dev/sourmash/sourmash compare -o rhizosphere_scaled${i}_k21 *${i}.sig
# done
# Out:
# 0-KBSCornC1_FD.fastq.gz.kmertrim	[ 1.     0.01   0.013  0.01   0.021  0.026  0.01   0.004  0.004  0.004
#   0.004  0.003  0.003  0.003  0.003  0.003  0.003  0.003  0.003  0.002
#   0.004  0.003  0.002  0.003]
# 1-KBSCornC2_FD.fastq.gz.kmertrim	[ 0.01   1.     0.009  0.009  0.01   0.01   0.008  0.005  0.007  0.006
#   0.006  0.005  0.004  0.004  0.004  0.005  0.005  0.004  0.005  0.003
#   0.005  0.004  0.004  0.004]
# 2-KBSCornC3_FD.fastq.gz.kmertrim	[ 0.013  0.009  1.     0.01   0.013  0.013  0.008  0.006  0.007  0.006
#   0.007  0.005  0.005  0.004  0.004  0.005  0.004  0.005  0.006  0.003
#   0.006  0.005  0.004  0.004]
# 3-KBSCornC4_FD.fastq.gz.kmertrim	[ 0.01   0.009  0.01   1.     0.01   0.01   0.007  0.007  0.008  0.008
#   0.008  0.006  0.005  0.005  0.006  0.006  0.006  0.005  0.007  0.004
#   0.007  0.006  0.004  0.005]
# 4-KBSCornC5_FD.fastq.gz.kmertrim	[ 0.021  0.01   0.013  0.01   1.     0.021  0.01   0.006  0.006  0.005
#   0.006  0.005  0.004  0.004  0.004  0.005  0.004  0.004  0.005  0.003
#   0.005  0.004  0.003  0.004]
# 5-KBSCornC6_FD.fastq.gz.kmertrim	[ 0.026  0.01   0.013  0.01   0.021  1.     0.018  0.005  0.005  0.005
#   0.005  0.004  0.003  0.003  0.003  0.004  0.003  0.003  0.004  0.003
#   0.004  0.003  0.003  0.003]
# 6-KBSCornC7_FD.fastq.gz.kmertrim	[ 0.01   0.008  0.008  0.007  0.01   0.018  1.     0.005  0.006  0.006
#   0.005  0.004  0.003  0.004  0.003  0.004  0.004  0.004  0.004  0.003
#   0.005  0.004  0.003  0.004]
# 7-KBSMisM7withPhiX_FD.fastq.gz.kmertrim	[ 0.004  0.005  0.006  0.007  0.006  0.005  0.005  1.     0.008  0.007
#   0.007  0.006  0.005  0.006  0.006  0.005  0.004  0.005  0.007  0.004
#   0.007  0.005  0.004  0.005]
# 8-KBSMiscanthusM1_FD.fastq.gz.kmertrim	[ 0.004  0.007  0.007  0.008  0.006  0.005  0.006  0.008  1.     0.008
#   0.009  0.006  0.005  0.006  0.006  0.006  0.006  0.005  0.007  0.003
#   0.007  0.005  0.004  0.005]
# 14-KBSMiswitspikein_FD.fastq.gz.kmertrim	[ 0.     0.006  0.011  0.006  0.     0.004  0.005  0.013  0.007  0.007
#   0.014  0.006  0.011  0.011  1.     0.     0.006  0.     0.015  0.01   0.
#   0.005  0.013  0.012]
# 15-KBSSwiS1_FD.fastq.gz.kmertrim	[ 0.003  0.005  0.005  0.005  0.007  0.004  0.004  0.005  0.005  0.011
#   0.011  0.005  0.005  0.     0.     1.     0.005  0.004  0.006  0.     0.011
#   0.004  0.     0.   ]
# 16-KBSSwiS2withPhiX_FD.fastq.gz.kmertrim	[ 0.     0.006  0.005  0.     0.     0.     0.     0.006  0.006  0.     0.
#   0.005  0.005  0.005  0.006  0.005  1.     0.     0.     0.005  0.     0.
#   0.006  0.   ]
# 17-KBSSwiS3_FD.fastq.gz.kmertrim	[ 0.003  0.005  0.005  0.005  0.004  0.004  0.004  0.005  0.011  0.005
#   0.006  0.005  0.     0.     0.     0.004  0.     1.     0.006  0.     0.005
#   0.009  0.     0.005]
# 18-KBSSwiS4_FD.fastq.gz.kmertrim	[ 0.004  0.007  0.012  0.013  0.005  0.009  0.018  0.015  0.008  0.015
#   0.017  0.006  0.     0.     0.015  0.006  0.     0.006  1.     0.006
#   0.008  0.012  0.007  0.021]
# 19-KBSSwiS5withPhiX_FD.fastq.gz.kmertrim	[ 0.     0.005  0.009  0.005  0.004  0.004  0.004  0.01   0.005  0.005
#   0.005  0.004  0.004  0.004  0.01   0.     0.005  0.     0.006  1.     0.
#   0.004  0.01   0.005]
# 20-KBSSwiS6_FD.fastq.gz.kmertrim	[ 0.003  0.013  0.006  0.006  0.004  0.004  0.006  0.007  0.007  0.007
#   0.015  0.006  0.     0.     0.     0.011  0.     0.005  0.008  0.     1.
#   0.006  0.     0.006]
# 21-KBSSwiS7_FD.fastq.gz.kmertrim	[ 0.003  0.005  0.009  0.01   0.004  0.008  0.009  0.011  0.006  0.011
#   0.012  0.005  0.     0.     0.005  0.004  0.     0.009  0.012  0.004
#   0.006  1.     0.     0.005]
# 22-KBSSwiwitspikein_2_FD.fastq.gz.kmertrim	[ 0.     0.006  0.005  0.     0.004  0.     0.     0.013  0.014  0.     0.
#   0.006  0.006  0.006  0.013  0.     0.006  0.     0.007  0.01   0.     0.
#   1.     0.006]
# 23-KBSSwiwitspikein_3_FD.fastq.gz.kmertrim	[ 0.003  0.     0.005  0.005  0.     0.004  0.005  0.006  0.006  0.006
#   0.013  0.     0.     0.     0.012  0.     0.     0.005  0.021  0.005
#   0.006  0.005  0.006  1.   ]
# # running sourmash subcommand: compare
# loading KBSCornC1_FD.fastq.gz.kmertrim.scaled100.sig
# loading KBSCornC2_FD.fastq.gz.kmertrim.scaled100.sig
# loading KBSCornC3_FD.fastq.gz.kmertrim.scaled100.sig
# loading KBSCornC4_FD.fastq.gz.kmertrim.scaled100.sig
# loading KBSCornC5_FD.fastq.gz.kmertrim.scaled100.sig
# loading KBSCornC6_FD.fastq.gz.kmertrim.scaled100.sig
# loading KBSCornC7_FD.fastq.gz.kmertrim.scaled100.sig
# loading KBSMisM7withPhiX_FD.fastq.gz.kmertrim.scaled100.sig
# loading KBSMiscanthusM1_FD.fastq.gz.kmertrim.scaled100.sig
# loading KBSMiscanthusM2_FD.fastq.gz.kmertrim.scaled100.sig
# loading KBSMiscanthusM3_FD.fastq.gz.kmertrim.scaled100.sig
# loading KBSMiscanthusM4_FD.fastq.gz.kmertrim.scaled100.sig
# loading KBSMiscanthusM5_FD.fastq.gz.kmertrim.scaled100.sig
# loading KBSMiscanthusM6_FD.fastq.gz.kmertrim.scaled100.sig
# loading KBSMiswitspikein_FD.fastq.gz.kmertrim.scaled100.sig
# loading KBSSwiS1_FD.fastq.gz.kmertrim.scaled100.sig
# loading KBSSwiS2withPhiX_FD.fastq.gz.kmertrim.scaled100.sig
# loading KBSSwiS3_FD.fastq.gz.kmertrim.scaled100.sig
# loading KBSSwiS4_FD.fastq.gz.kmertrim.scaled100.sig
# loading KBSSwiS5withPhiX_FD.fastq.gz.kmertrim.scaled100.sig
# loading KBSSwiS6_FD.fastq.gz.kmertrim.scaled100.sig
# loading KBSSwiS7_FD.fastq.gz.kmertrim.scaled100.sig
# loading KBSSwiwitspikein_2_FD.fastq.gz.kmertrim.scaled100.sig
# loading KBSSwiwitspikein_3_FD.fastq.gz.kmertrim.scaled100.sig
# min similarity in matrix: 0.0020426658227483924
# saving labels to: rhizosphere_scaled100_k21.labels.txt
# saving distance matrix to: rhizosphere_scaled100_k21
# # running sourmash subcommand: compare
# loading KBSCornC1_FD.fastq.gz.kmertrim.scaled500.sig
# loading KBSCornC2_FD.fastq.gz.kmertrim.scaled500.sig
# loading KBSCornC3_FD.fastq.gz.kmertrim.scaled500.sig
# loading KBSCornC4_FD.fastq.gz.kmertrim.scaled500.sig
# loading KBSCornC5_FD.fastq.gz.kmertrim.scaled500.sig
# loading KBSCornC6_FD.fastq.gz.kmertrim.scaled500.sig
# loading KBSCornC7_FD.fastq.gz.kmertrim.scaled500.sig
# loading KBSMisM7withPhiX_FD.fastq.gz.kmertrim.scaled500.sig
# loading KBSMiscanthusM1_FD.fastq.gz.kmertrim.scaled500.sig
# loading KBSMiscanthusM2_FD.fastq.gz.kmertrim.scaled500.sig
# loading KBSMiscanthusM3_FD.fastq.gz.kmertrim.scaled500.sig
# loading KBSMiscanthusM4_FD.fastq.gz.kmertrim.scaled500.sig
# loading KBSMiscanthusM5_FD.fastq.gz.kmertrim.scaled500.sig
# loading KBSMiscanthusM6_FD.fastq.gz.kmertrim.scaled500.sig
# loading KBSMiswitspikein_FD.fastq.gz.kmertrim.scaled500.sig
# loading KBSSwiS1_FD.fastq.gz.kmertrim.scaled500.sig
# loading KBSSwiS2withPhiX_FD.fastq.gz.kmertrim.scaled500.sig
# loading KBSSwiS3_FD.fastq.gz.kmertrim.scaled500.sig
# loading KBSSwiS4_FD.fastq.gz.kmertrim.scaled500.sig
# loading KBSSwiS5withPhiX_FD.fastq.gz.kmertrim.scaled500.sig
# loading KBSSwiS6_FD.fastq.gz.kmertrim.scaled500.sig
# loading KBSSwiS7_FD.fastq.gz.kmertrim.scaled500.sig
# loading KBSSwiwitspikein_2_FD.fastq.gz.kmertrim.scaled500.sig
# loading KBSSwiwitspikein_3_FD.fastq.gz.kmertrim.scaled500.sig
# min similarity in matrix: 0.0017642907551164433
# saving labels to: rhizosphere_scaled500_k21.labels.txt
# saving distance matrix to: rhizosphere_scaled500_k21
# # running sourmash subcommand: compare
# loading KBSCornC1_FD.fastq.gz.kmertrim.scaled1000.sig
# loading KBSCornC2_FD.fastq.gz.kmertrim.scaled1000.sig
# loading KBSCornC3_FD.fastq.gz.kmertrim.scaled1000.sig
# loading KBSCornC4_FD.fastq.gz.kmertrim.scaled1000.sig
# loading KBSCornC5_FD.fastq.gz.kmertrim.scaled1000.sig
# loading KBSCornC6_FD.fastq.gz.kmertrim.scaled1000.sig
# loading KBSCornC7_FD.fastq.gz.kmertrim.scaled1000.sig
# loading KBSMisM7withPhiX_FD.fastq.gz.kmertrim.scaled1000.sig
# loading KBSMiscanthusM1_FD.fastq.gz.kmertrim.scaled1000.sig
# loading KBSMiscanthusM2_FD.fastq.gz.kmertrim.scaled1000.sig
# loading KBSMiscanthusM3_FD.fastq.gz.kmertrim.scaled1000.sig
# loading KBSMiscanthusM4_FD.fastq.gz.kmertrim.scaled1000.sig
# loading KBSMiscanthusM5_FD.fastq.gz.kmertrim.scaled1000.sig
# loading KBSMiscanthusM6_FD.fastq.gz.kmertrim.scaled1000.sig
# loading KBSMiswitspikein_FD.fastq.gz.kmertrim.scaled1000.sig
# loading KBSSwiS1_FD.fastq.gz.kmertrim.scaled1000.sig
# loading KBSSwiS2withPhiX_FD.fastq.gz.kmertrim.scaled1000.sig
# loading KBSSwiS3_FD.fastq.gz.kmertrim.scaled1000.sig
# loading KBSSwiS4_FD.fastq.gz.kmertrim.scaled1000.sig
# loading KBSSwiS5withPhiX_FD.fastq.gz.kmertrim.scaled1000.sig
# loading KBSSwiS6_FD.fastq.gz.kmertrim.scaled1000.sig
# loading KBSSwiS7_FD.fastq.gz.kmertrim.scaled1000.sig
# loading KBSSwiwitspikein_2_FD.fastq.gz.kmertrim.scaled1000.sig
# loading KBSSwiwitspikein_3_FD.fastq.gz.kmertrim.scaled1000.sig
# min similarity in matrix: 0.0015762925598991173
# saving labels to: rhizosphere_scaled1000_k21.labels.txt
# saving distance matrix to: rhizosphere_scaled1000_k21
# # running sourmash subcommand: compare
# loading KBSCornC1_FD.fastq.gz.kmertrim.scaled5000.sig
# loading KBSCornC2_FD.fastq.gz.kmertrim.scaled5000.sig
# loading KBSCornC3_FD.fastq.gz.kmertrim.scaled5000.sig
# loading KBSCornC4_FD.fastq.gz.kmertrim.scaled5000.sig
# loading KBSCornC5_FD.fastq.gz.kmertrim.scaled5000.sig
# loading KBSCornC6_FD.fastq.gz.kmertrim.scaled5000.sig
# loading KBSCornC7_FD.fastq.gz.kmertrim.scaled5000.sig
# loading KBSMisM7withPhiX_FD.fastq.gz.kmertrim.scaled5000.sig
# loading KBSMiscanthusM1_FD.fastq.gz.kmertrim.scaled5000.sig
# loading KBSMiscanthusM2_FD.fastq.gz.kmertrim.scaled5000.sig
# loading KBSMiscanthusM3_FD.fastq.gz.kmertrim.scaled5000.sig
# loading KBSMiscanthusM4_FD.fastq.gz.kmertrim.scaled5000.sig
# loading KBSMiscanthusM5_FD.fastq.gz.kmertrim.scaled5000.sig
# loading KBSMiscanthusM6_FD.fastq.gz.kmertrim.scaled5000.sig
# loading KBSMiswitspikein_FD.fastq.gz.kmertrim.scaled5000.sig
# loading KBSSwiS1_FD.fastq.gz.kmertrim.scaled5000.sig
# loading KBSSwiS2withPhiX_FD.fastq.gz.kmertrim.scaled5000.sig
# loading KBSSwiS3_FD.fastq.gz.kmertrim.scaled5000.sig
# loading KBSSwiS4_FD.fastq.gz.kmertrim.scaled5000.sig
# loading KBSSwiS5withPhiX_FD.fastq.gz.kmertrim.scaled5000.sig
# loading KBSSwiS6_FD.fastq.gz.kmertrim.scaled5000.sig
# loading KBSSwiS7_FD.fastq.gz.kmertrim.scaled5000.sig
# loading KBSSwiwitspikein_2_FD.fastq.gz.kmertrim.scaled5000.sig
# loading KBSSwiwitspikein_3_FD.fastq.gz.kmertrim.scaled5000.sig
# min similarity in matrix: 0.0
# saving labels to: rhizosphere_scaled5000_k21.labels.txt
# saving distance matrix to: rhizosphere_scaled5000_k21
# # running sourmash subcommand: compare
# loading KBSCornC1_FD.fastq.gz.kmertrim.scaled10000.sig
# loading KBSCornC2_FD.fastq.gz.kmertrim.scaled10000.sig
# loading KBSCornC3_FD.fastq.gz.kmertrim.scaled10000.sig
# loading KBSCornC4_FD.fastq.gz.kmertrim.scaled10000.sig
# loading KBSCornC5_FD.fastq.gz.kmertrim.scaled10000.sig
# loading KBSCornC6_FD.fastq.gz.kmertrim.scaled10000.sig
# loading KBSCornC7_FD.fastq.gz.kmertrim.scaled10000.sig
# loading KBSMisM7withPhiX_FD.fastq.gz.kmertrim.scaled10000.sig
# loading KBSMiscanthusM1_FD.fastq.gz.kmertrim.scaled10000.sig
# loading KBSMiscanthusM2_FD.fastq.gz.kmertrim.scaled10000.sig
# loading KBSMiscanthusM3_FD.fastq.gz.kmertrim.scaled10000.sig
# loading KBSMiscanthusM4_FD.fastq.gz.kmertrim.scaled10000.sig
# loading KBSMiscanthusM5_FD.fastq.gz.kmertrim.scaled10000.sig
# loading KBSMiscanthusM6_FD.fastq.gz.kmertrim.scaled10000.sig
# loading KBSMiswitspikein_FD.fastq.gz.kmertrim.scaled10000.sig
# loading KBSSwiS1_FD.fastq.gz.kmertrim.scaled10000.sig
# loading KBSSwiS2withPhiX_FD.fastq.gz.kmertrim.scaled10000.sig
# loading KBSSwiS3_FD.fastq.gz.kmertrim.scaled10000.sig
# loading KBSSwiS4_FD.fastq.gz.kmertrim.scaled10000.sig
# loading KBSSwiS5withPhiX_FD.fastq.gz.kmertrim.scaled10000.sig
# loading KBSSwiS6_FD.fastq.gz.kmertrim.scaled10000.sig
# loading KBSSwiS7_FD.fastq.gz.kmertrim.scaled10000.sig
# loading KBSSwiwitspikein_2_FD.fastq.gz.kmertrim.scaled10000.sig
# loading KBSSwiwitspikein_3_FD.fastq.gz.kmertrim.scaled10000.sig
# min similarity in matrix: 0.0
# saving labels to: rhizosphere_scaled10000_k21.labels.txt
# saving distance matrix to: rhizosphere_scaled10000_k21
# # running sourmash subcommand: compare
# loading KBSCornC1_FD.fastq.gz.kmertrim.scaled20000.sig
# loading KBSCornC2_FD.fastq.gz.kmertrim.scaled20000.sig
# loading KBSCornC3_FD.fastq.gz.kmertrim.scaled20000.sig
# loading KBSCornC4_FD.fastq.gz.kmertrim.scaled20000.sig
# loading KBSCornC5_FD.fastq.gz.kmertrim.scaled20000.sig
# loading KBSCornC6_FD.fastq.gz.kmertrim.scaled20000.sig
# loading KBSCornC7_FD.fastq.gz.kmertrim.scaled20000.sig
# loading KBSMisM7withPhiX_FD.fastq.gz.kmertrim.scaled20000.sig
# loading KBSMiscanthusM1_FD.fastq.gz.kmertrim.scaled20000.sig
# loading KBSMiscanthusM2_FD.fastq.gz.kmertrim.scaled20000.sig
# loading KBSMiscanthusM3_FD.fastq.gz.kmertrim.scaled20000.sig
# loading KBSMiscanthusM4_FD.fastq.gz.kmertrim.scaled20000.sig
# loading KBSMiscanthusM5_FD.fastq.gz.kmertrim.scaled20000.sig
# loading KBSMiscanthusM6_FD.fastq.gz.kmertrim.scaled20000.sig
# loading KBSMiswitspikein_FD.fastq.gz.kmertrim.scaled20000.sig
# loading KBSSwiS1_FD.fastq.gz.kmertrim.scaled20000.sig
# loading KBSSwiS2withPhiX_FD.fastq.gz.kmertrim.scaled20000.sig
# loading KBSSwiS3_FD.fastq.gz.kmertrim.scaled20000.sig
# loading KBSSwiS4_FD.fastq.gz.kmertrim.scaled20000.sig
# loading KBSSwiS5withPhiX_FD.fastq.gz.kmertrim.scaled20000.sig
# loading KBSSwiS6_FD.fastq.gz.kmertrim.scaled20000.sig
# loading KBSSwiS7_FD.fastq.gz.kmertrim.scaled20000.sig
# loading KBSSwiwitspikein_2_FD.fastq.gz.kmertrim.scaled20000.sig
# loading KBSSwiwitspikein_3_FD.fastq.gz.kmertrim.scaled20000.sig
# min similarity in matrix: 0.0
# saving labels to: rhizosphere_scaled20000_k21.labels.txt
# saving distance matrix to: rhizosphere_scaled20000_k21

# %%
D, labels = fig.load_matrix_and_labels('rhizosphere_scaled500_k21')
D = (D + D.T) / 0.1
_ = fig.plot_composite_matrix(D, labels, vmin=0.0)
numpy.min(D), numpy.max(D)



D, labels = fig.load_matrix_and_labels('rhizosphere_scaled5000_k21')
D = (D + D.T) / 0.1
_ = fig.plot_composite_matrix(D, labels, vmin=0.0)
numpy.min(D), numpy.max(D)
# Out:
# (0.0, 20.0)
